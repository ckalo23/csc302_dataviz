# %% [markdown]
# Import content drive and pandas for notebook access.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %% [markdown]
# (2) Use pandas to read the olympic_medals.csv from the DATA folder on Google Drive. Then perform the followings by
# using pandas and/or Python built-in functions.
#
# 2-a) Find the size of the data frame. How many rows, how many columns?

# %%
df = pd.read_csv('/content/drive/MyDrive/DATA/olympic_medals.csv')

display(df)
df.shape
# Out:
#      Gender  \
# 0       M
# 1       M
# 2       M
# 3       M
# 4       M
# ...     ...
# 2389    W
# 2390    W
# 2391    W
# 2392    W
# 2393    W
#
#            Event         \
# 0            10000M Men
# 1            10000M Men
# 2            10000M Men
# 3            10000M Men
# 4            10000M Men
# ...                 ...
# 2389  Triple Jump Women
# 2390  Triple Jump Women
# 2391  Triple Jump Women
# 2392  Triple Jump Women
# 2393  Triple Jump Women
#
#      Location  \
# 0         Rio
# 1         Rio
# 2         Rio
# 3     Beijing
# 4     Beijing
# ...       ...
# 2389   Athens
# 2390   Athens
# 2391  Atlanta
# 2392  Atlanta
# 2393  Atlanta
#
#       Year  \
# 0     2016
# 1     2016
# 2     2016
# 3     2008
# 4     2008
# ...    ...
# 2389  2004
# 2390  2004
# 2391  1996
# 2392  1996
# 2393  1996
#
#      Medal  \
# 0       G
# 1       S
# 2       B
# 3       G
# 4       S
# ...    ...
# 2389    S
# 2390    B
# 2391    G
# 2392    S
# 2393    B
#
# ...

# %% [markdown]
#     There are 2,394 rows and 8 columns in the dataframe containing the olympic medal csv.

# %% [markdown]
# 2-b) Use the appropriate function to report the data types for all columns.

# %%
df.dtypes
# Out:
# Gender         object
# Event          object
# Location       object
# Year            int64
# Medal          object
# Name           object
# Nationality    object
# Result         object
# dtype: object

# %% [markdown]
#     The data types for all the columns are **object**, except for the *year*, which is a **64-bit integer**.

# %% [markdown]
# 2-c) Find how many unique locations olympics were held at.

# %%
df['Location'].unique() #this only prints array of unique locations

len(df['Location'].unique()) #this prints length of the above array
# Out:
# 23

# %% [markdown]
#     There are 23 unique locations for the Olympics.

# %% [markdown]
# 2-d) Find how many medals the USA team won in total.

# %%
len(df[df['Nationality']=='USA'])
# Out:
# 638

# %% [markdown]
#     There have been 638 medals won by the USA team in total.

# %% [markdown]
# 2-e) Find the total number of medals for each Nationality. (Hint: please search for groupby() function with count)

# %% [markdown]
#     **This block below sets pandas display() option to show entire dataframe.

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('display.colheader_justify', 'center')
pd.set_option('display.precision', 3)

# %%
display(df.groupby('Nationality').count().sort_values('Medal', ascending = False).Medal)

# %% [markdown]
# (3) Use pandas to read the *causes_of_death.csv* from the DATA folder on Google Drive. Then perform the followings
# by using pandas and/or Python built-in functions.
#
# 3-a) Find the size of the data frame. How many rows, how many columns?

# %%
pd.reset_option('display') #limits pandas display to show 5 at head and tail of data frame, instead of all elements like previously

# %%
cd = pd.read_csv('/content/drive/MyDrive/DATA/causes_of_death.csv')

display(cd)
cd.shape
# Out:
#         State  State Code Ten-Year Age Groups  ... Deaths Population Crude Rate
# 0     Alabama           1            < 1 year  ...     14     3579.0        NaN
# 1     Alabama           1            < 1 year  ...     24     7443.0      322.5
# 2     Alabama           1            < 1 year  ...   2093   169339.0     1236.0
# 3     Alabama           1            < 1 year  ...   2144   347921.0      616.2
# 4     Alabama           1            < 1 year  ...     33     7366.0      448.0
# ...       ...         ...                 ...  ...    ...        ...        ...
# 4110  Wyoming          56           85+ years  ...  13140    95575.0    13748.4
# 4111  Wyoming          56           85+ years  ...     41      356.0    11516.9
# 4112  Wyoming          56           85+ years  ...     12      244.0        NaN
# 4113  Wyoming          56           85+ years  ...     32      454.0     7048.5
# 4114  Wyoming          56           85+ years  ...   7982    49954.0    15978.7
#
# ...

# %% [markdown]
#     There are 4,115 rows and 11 columns in the dataframe containing the cause of death csv.

# %% [markdown]
# 3-b) What is the average death count across the country?

# %%
from statistics import mean
mean(cd.Deaths)
# Out:
# 10914.44957472661

# %% [markdown]
# 3-c) What is the total death count for each state. (Hint: please search for groupby() function with sum)

# %%
cd2 = cd[['State', 'Deaths']]
display(cd2.groupby('State').sum('Death'))

#cd2 = cd.loc[:,['State', 'Deaths']]    this works as well inst. of 1st

# %% [markdown]
# 3-d) What is the average death count for each state. (Hint: please search for groupby() function with mean)

# %%
display(cd2.groupby('State').mean('Death'))
# Out:
#                             Deaths
# State
# Alabama               10626.913580
# Alaska                  772.365854
# Arizona                9109.717391
# Arkansas               6455.728395
# California            45819.797872
# Colorado               6378.215909
# Connecticut            6559.135802
# Delaware               1970.043478
# District of Columbia   1447.276923
# Florida               34790.122222
# Georgia               14639.732558
# Hawaii                 2266.368421
# Idaho                  2778.847222
# Illinois              21519.206897
# Indiana               12895.425000
# Iowa                   6185.939024
# Kansas                 5407.566265
# Kentucky               9902.434211
# Louisiana              9107.397590
# Maine                  3310.800000
# Maryland               9201.264368
# Massachusetts         12185.567901
# Michigan              17976.876404
# Minnesota              7980.500000
# Mississippi            6117.755814
# ...

# %% [markdown]
# 3-e) What is the total death count for males and females in each state. (Hint: groupby() function with sum, but you
# will have two attributes/columns for the groupby() )

# %%
display(cd.groupby(['State','Gender']).sum('Death'))
# Out:
#                       State Code  Deaths  Population  Crude Rate
# State         Gender
# Alabama       Female          40  430133  43148507.0     69294.4
#               Male            41  430647  40597842.0     86614.7
# Alaska        Female          80   27199   5761611.0     77863.9
#               Male            84   36135   6379314.0    100396.4
# Arizona       Female         180  396028  54846072.0     73199.1
# ...                          ...     ...         ...         ...
# West Virginia Male          1674  192560  16087802.0     76930.9
# Wisconsin     Female        2420  436397  50807788.0     83793.6
#               Male          2420  421232  49954108.0    107111.4
# Wyoming       Female        1792   37153   4696239.0     66382.2
#               Male          1960   40233   4872826.0     68545.2
#
# [102 rows x 4 columns]

# %% [markdown]
# 3-f) Drop your rows which have NA in it. Then verify it by using head() to show they are removed. (Hint: dropna())

# %%
cd.dropna()
cd.head()
# Out:
#      State  State Code Ten-Year Age Groups  ... Deaths Population Crude Rate
# 0  Alabama           1            < 1 year  ...     14     3579.0        NaN
# 1  Alabama           1            < 1 year  ...     24     7443.0      322.5
# 2  Alabama           1            < 1 year  ...   2093   169339.0     1236.0
# 3  Alabama           1            < 1 year  ...   2144   347921.0      616.2
# 4  Alabama           1            < 1 year  ...     33     7366.0      448.0
#
# [5 rows x 11 columns]

# %% [markdown]
# 3-g) Create a column called ratio and assign the ratio of death counts to population to fill its values. Then verify it
# by using head().

# %%
cd['Ratio'] = cd.Deaths/cd.Population
cd.head()
# Out:
#      State  State Code Ten-Year Age Groups  ... Population Crude Rate     Ratio
# 0  Alabama           1            < 1 year  ...     3579.0        NaN  0.003912
# 1  Alabama           1            < 1 year  ...     7443.0      322.5  0.003225
# 2  Alabama           1            < 1 year  ...   169339.0     1236.0  0.012360
# 3  Alabama           1            < 1 year  ...   347921.0      616.2  0.006162
# 4  Alabama           1            < 1 year  ...     7366.0      448.0  0.004480
#
# [5 rows x 12 columns]

# %% [markdown]
# 3-h) Select only rows where Ten-Year Age Groups Code is equal to 1. Notice that this column has string data type.

# %%
cd[cd['Ten-Year Age Groups Code']=='1']
# Out:
#         State  State Code Ten-Year Age Groups  ... Population Crude Rate     Ratio
# 0     Alabama           1            < 1 year  ...     3579.0        NaN  0.003912
# 1     Alabama           1            < 1 year  ...     7443.0      322.5  0.003225
# 2     Alabama           1            < 1 year  ...   169339.0     1236.0  0.012360
# 3     Alabama           1            < 1 year  ...   347921.0      616.2  0.006162
# 4     Alabama           1            < 1 year  ...     7366.0      448.0  0.004480
# ...       ...         ...                 ...  ...        ...        ...       ...
# 4048  Wyoming          56            < 1 year  ...     3260.0        NaN  0.005828
# 4049  Wyoming          56            < 1 year  ...    57791.0      565.8  0.005658
# 4050  Wyoming          56            < 1 year  ...     3366.0     1218.1  0.012181
# 4051  Wyoming          56            < 1 year  ...     1572.0        NaN  0.006997
# ...

# %% [markdown]
# 3-i) Use the selected rows above (you can either assign to another variable or keep using dot(.) operator) to chain
# with other functions (groupby, sum, sort_values) to view your data sorted from the highest Crude rate to
# the smallest. This will show the infant mortality rate for all states.

# %%
cd[cd['Ten-Year Age Groups Code']=='1'].groupby('State').sum().sort_values('Crude Rate', ascending=False)
# Out:
#                       State Code  Deaths  Population  Crude Rate     Ratio
# State
# Mississippi                  224    7441    735284.0      7682.7  0.076828
# Oklahoma                     320    7324    922219.0      6723.5  0.067236
# North Carolina               296   17430   2160788.0      6442.4  0.064424
# Wisconsin                    440    7909   1239313.0      6417.3  0.064173
# Michigan                     208   16513   2184807.0      6219.8  0.062199
# Kansas                       160    4885    709234.0      5850.7  0.058507
# Arizona                       32   10153   1571511.0      5602.3  0.056023
# Minnesota                    216    6477   1239873.0      5526.6  0.055265
# South Dakota                 276    1440    201855.0      5499.9  0.054999
# North Dakota                 228    1059    157084.0      5489.9  0.054900
# Alaska                        16    1176    189233.0      5437.9  0.054377
# ...
